# %%
import pandas as pd

# %%
df1= pd.read_csv('Exercise 1.csv')

# %%
df1
# Out:
#                      Exercise              Equipment   Exercise Type  \
# 0                Arnold Press              Dumbbells          Weight
# 1                  Bicep Curl    Bar,Dumbbells,Cable  Weight,Machine
# 2              Bicycle Crunch            Body Weight          Weight
# 3                      Bounds            Body Weight     Cardio,Laps
# 4                   Box Jumps            Body Weight            Plyo
# ..                        ...                    ...             ...
# 83  Twisted Mountain Climbers  Body Weight,Bosu Ball          Cardio
# 84                  Wall Ball          Medicine Ball          Cardio
# 85     Weighted Jumping Jacks              Dumbbells          Cardio
# 86           Weighted Punches              Dumbbells          Cardio
# 87                    Deadbug            Body Weight          Weight
#
#       Major Muscle        Minor Muscle  \
# 0             Arms     Bicep,Shoulders
# 1             Arms               Bicep
# ...
