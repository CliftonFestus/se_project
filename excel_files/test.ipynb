# %%
import pandas as pd
# %ls
# Out:
# 'Advanced Workout Plan-converted.xlsx'
#  Beginner-converted.xlsx
# 'Beginner Day 1-converted.xlsx'
# 'Beginner Day 2-converted.xlsx'
# 'Beginner Day 3-converted.xlsx'
# 'Beginner Day 4-converted.xlsx'
# 'Beginner Day 5-converted.xlsx'
# 'Diet Plan (Beginner)-converted.xlsx'
# 'Exercise 1.csv'
# 'Fat Loss Diet Plan (Females)-converted.xlsx'
# 'Intermidiate Diet Plan-converted.xlsx'
# 'Intermidiate Muscle Building (Men)-converted.xlsx'
# 'Muscle Gain Diet Plan (Men)-converted.xlsx'
#  test.ipynb
#  xcel1.xlsx

# %%
logins= pd.read_excel('../logins.xlsx', index_col= 'user')
logins_dict = logins.to_dict()

# %%
logins_dict
# Out:
# {'password': {'Aditya_N': 1234,
#   'Arslan_M': 2345,
#   'Clifton_F': 3456,
#   'Rohan_R': 4567,
#   'Shashank_K': 5678,
#   'Chirayu_P': 6789}}

# %%
username = input('Username:  ')
# Out:
# Username:  Aditya_N

# %%
if username in logins.index:
    print('Valid username')
# Out:
# Valid username

# %%
logins_dict['password']['Aditya_N']
# Out:
# 1234

# %%
logins.index
# Out:
# Index(['Aditya_N', 'Arslan_M', 'Clifton_F', 'Rohan_R', 'Shashank_K',
#        'Chirayu_P'],
#       dtype='object', name='user')

# %%
exc= pd.read_csv('../Exercise Final.csv')
exc
# Out:
#                      Exercise              Equipment   Exercise Type  \
# 0                Arnold Press              Dumbbells          Weight
# 1                  Bicep Curl    Bar,Dumbbells,Cable  Weight,Machine
# 2              Bicycle Crunch            Body Weight          Weight
# 3                      Bounds            Body Weight     Cardio,Laps
# 4                   Box Jumps            Body Weight            Plyo
# ..                        ...                    ...             ...
# 83  Twisted Mountain Climbers  Body Weight,Bosu Ball          Cardio
# 84                  Wall Ball          Medicine Ball          Cardio
# 85     Weighted Jumping Jacks              Dumbbells          Cardio
# 86           Weighted Punches              Dumbbells          Cardio
# 87                    Deadbug            Body Weight          Weight
#
#       Major Muscle        Minor Muscle  \
# 0             Arms     Bicep,Shoulders
# 1             Arms               Bicep
# ...

# %%
exc[exc['Excercise'] [exc['Goal'] isin(['Bulking'])]
# Out:
#   File "/tmp/ipykernel_12044/1906111925.py", line 1
#     exc[exc['Excercise'] [exc['Goal'] isin(['Bulking'])]
#                                       ^
# SyntaxError: invalid syntax
